# %%
import seaborn as sns
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = 'Data_files\\College_Data'
college = pd.read_csv(path)

# %%
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 19 columns):
# Unnamed: 0     777 non-null object
# Private        777 non-null object
# Apps           777 non-null int64
# Accept         777 non-null int64
# Enroll         777 non-null int64
# Top10perc      777 non-null int64
# Top25perc      777 non-null int64
# F.Undergrad    777 non-null int64
# P.Undergrad    777 non-null int64
# Outstate       777 non-null int64
# Room.Board     777 non-null int64
# Books          777 non-null int64
# Personal       777 non-null int64
# PhD            777 non-null int64
# Terminal       777 non-null int64
# S.F.Ratio      777 non-null float64
# perc.alumni    777 non-null int64
# Expend         777 non-null int64
# Grad.Rate      777 non-null int64
# dtypes: float64(1), int64(16), object(2)
# memory usage: 115.5+ KB

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
college.isnull().sum()
# Out:
# Unnamed: 0     0
# Private        0
# Apps           0
# Accept         0
# Enroll         0
# Top10perc      0
# Top25perc      0
# F.Undergrad    0
# P.Undergrad    0
# Outstate       0
# Room.Board     0
# Books          0
# Personal       0
# PhD            0
# Terminal       0
# S.F.Ratio      0
# perc.alumni    0
# Expend         0
# Grad.Rate      0
# dtype: int64

# %%
college.columns
# Out:
# Index(['Unnamed: 0', 'Private', 'Apps', 'Accept', 'Enroll', 'Top10perc',
#        'Top25perc', 'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board',
#        'Books', 'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni',
#        'Expend', 'Grad.Rate'],
#       dtype='object')

# %%
college[['Unnamed: 0', 'Private']]
# Out:
#                          Unnamed: 0 Private
# 0      Abilene Christian University     Yes
# 1                Adelphi University     Yes
# 2                    Adrian College     Yes
# 3               Agnes Scott College     Yes
# 4         Alaska Pacific University     Yes
# ..                              ...     ...
# 772         Worcester State College      No
# 773               Xavier University     Yes
# 774  Xavier University of Louisiana     Yes
# 775                 Yale University     Yes
# 776    York College of Pennsylvania     Yes
#
# [777 rows x 2 columns]

# %%
college.drop(['Unnamed: 0', 'Private'], axis= 1, inplace= True)

# %%
plt.figure(figsize= (14,6))
sns.set_style("whitegrid")
sns.scatterplot(data= college ,x= 'Grad.Rate', y= 'Room.Board', palette= "Blues_r")

# %%
plt.figure(figsize= (14,6))
sns.set_style("whitegrid")
sns.scatterplot(data= college ,x= 'F.Undergrad', y= 'Outstate' , palette= "Blues_r")

# %%
plt.figure(figsize= (14,6))
college['Grad.Rate'].hist(bins = 50)

# %%
college[college['Grad.Rate'] > 100]
# Out:
#     Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  P.Undergrad  \
# 95  3847    3433     527          9         35         1010           12
#
#     Outstate  Room.Board  Books  Personal  PhD  Terminal  S.F.Ratio  \
# 95      9384        4840    600       500   22        47       14.3
#
#     perc.alumni  Expend  Grad.Rate
# 95           20    7697        118

# %%
college.drop(95,inplace=True)

# %%
plt.figure(figsize= (14,6))
college['Grad.Rate'].hist(bins = 50)

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters= 2)

# %%
college
# Out:
#       Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  P.Undergrad  \
# 0     1660    1232     721         23         52         2885          537
# 1     2186    1924     512         16         29         2683         1227
# 2     1428    1097     336         22         50         1036           99
# 3      417     349     137         60         89          510           63
# 4      193     146      55         16         44          249          869
# ..     ...     ...     ...        ...        ...          ...          ...
# 772   2197    1515     543          4         26         3089         2029
# 773   1959    1805     695         24         47         2849         1107
# 774   2097    1915     695         34         61         2793          166
# 775  10705    2453    1317         95         99         5217           83
# 776   2989    1855     691         28         63         2988         1726
#
# ...

# %%
km.fit(college)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
college['cluster'] = km.labels_

# %%
college.head()
# Out:
#    Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  P.Undergrad  \
# 0  1660    1232     721         23         52         2885          537
# 1  2186    1924     512         16         29         2683         1227
# 2  1428    1097     336         22         50         1036           99
# 3   417     349     137         60         89          510           63
# 4   193     146      55         16         44          249          869
#
#    Outstate  Room.Board  Books  Personal  PhD  Terminal  S.F.Ratio  \
# 0      7440        3300    450      2200   70        78       18.1
# 1     12280        6450    750      1500   29        30       12.2
# 2     11250        3750    400      1165   53        66       12.9
# 3     12960        5450    450       875   92        97        7.7
# 4      7560        4120    800      1500   76        72       11.9
#
#    perc.alumni  Expend  Grad.Rate  cluster
# 0           12    7041         60        0
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components= 2)

# %%
pca.fit(college)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
College_pca = pca.transform(college)

# %%
print('Before PCA: ', college.shape)
print('After PCA: ', College_pca.shape)
# Out:
# Before PCA:  (776, 18)
# After PCA:  (776, 2)

# %%
plt.figure(figsize=(12,6))
plt.scatter(College_pca[:,0],College_pca[:,1], c = college['cluster'],cmap='cool')
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')
